# %%
import pandas as pd

# %%
h=('uday','17-11-1997','male')
s=pd.Series(h)
s
# Out:
# 0          uday
# 1    17-11-1997
# 2          male
# dtype: object

# %%
pd.Series()
# Out:
# Series([], dtype: float64)

# %%
import numpy as np
d=np.arange(5)
p=pd.Series(d,index=[9,8,7,5,4])
p
# Out:
# 9    0
# 8    1
# 7    2
# 5    3
# 4    4
# dtype: int32

# %%
n={'a':1,'b':2,'c':3}
m=pd.Series(n,index=['a','b','a'])
m
# Out:
# a    1
# b    2
# a    1
# dtype: int64

# %%
m[['a','b']]
# Out:
# a    1
# a    1
# b    2
# dtype: int64

# %%
m=pd.Series([1,2,3,4],index=['a','b','c','d'])
m
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
l=pd.Series(5,index=[1,2,3,4])
l
# Out:
# 1    5
# 2    5
# 3    5
# 4    5
# dtype: int64

# %%
m[-4:]
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %% [markdown]
# ### m[0]

# %%
m[-1:]
# Out:
# d    4
# dtype: int64

# %%
m[:3]
m
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
m
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64

# %%
print(m)
m[-2:]
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# c    3
# d    4
# dtype: int64

# %%
m['b']
# Out:
# 2

# %%
data=[[1,1000],[2,2000],[3,3000]]
d=pd.DataFrame(data,index=['a','b','c'],columns=['one','two'])
print(d)
# Out:
#    one   two
# a    1  1000
# b    2  2000
# c    3  3000

# %%
data={'name':[1,2,3,4,5],'age':[100,200,300,400,500]}
d=pd.DataFrame(data,index=['a','b','c','d','e'])
d
# Out:
#    name  age
# a     1  100
# b     2  200
# c     3  300
# d     4  400
# e     5  500

# %%
data=[{1:100,2:200,3:300,4:400},{5:500,6:600,7:700},{5:500,6:600,7:700}]
l=pd.DataFrame(data)
l
# Out:
#        1      2      3      4      5      6      7
# 0  100.0  200.0  300.0  400.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN  500.0  600.0  700.0
# 2    NaN    NaN    NaN    NaN  500.0  600.0  700.0

# %%
d={'one':pd.DataFrame(data)
  ,'two':pd.DataFrame(data)}
d
# Out:
# {'one':        1      2      3      4      5      6      7
#  0  100.0  200.0  300.0  400.0    NaN    NaN    NaN
#  1    NaN    NaN    NaN    NaN  500.0  600.0  700.0
#  2    NaN    NaN    NaN    NaN  500.0  600.0  700.0,
#  'two':        1      2      3      4      5      6      7
#  0  100.0  200.0  300.0  400.0    NaN    NaN    NaN
#  1    NaN    NaN    NaN    NaN  500.0  600.0  700.0
#  2    NaN    NaN    NaN    NaN  500.0  600.0  700.0}

# %%
d['two']
# Out:
#        1      2      3      4      5      6      7
# 0  100.0  200.0  300.0  400.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN  500.0  600.0  700.0
# 2    NaN    NaN    NaN    NaN  500.0  600.0  700.0

# %%
l.iloc[0]
# Out:
# 1    100.0
# 2    200.0
# 3    300.0
# 4    400.0
# 5      NaN
# 6      NaN
# 7      NaN
# Name: 0, dtype: float64

# %%
l.drop(2)
# Out:
#        1      2      3      4      5      6      7
# 0  100.0  200.0  300.0  400.0    NaN    NaN    NaN
# 1    NaN    NaN    NaN    NaN  500.0  600.0  700.0

# %%
data = { 'name' : ['AA', 'IBM', 'GOOG'],
... 'date' : ['2001-12-01', '2012-02-10', '2010-04-09'],
... 'shares' : [100, 30, 90],
... 'price' : [12.3, 10.3, 32.2]
... }
dt=pd.DataFrame(data)
dt
# Out:
#    name        date  shares  price
# 0    AA  2001-12-01     100   12.3
# 1   IBM  2012-02-10      30   10.3
# 2  GOOG  2010-04-09      90   32.2

# %%
dt['owner']='unknown'

# %%
dt
# Out:
#    name        date  shares  price    owner
# 0    AA  2001-12-01     100   12.3  unknown
# 1   IBM  2012-02-10      30   10.3  unknown
# 2  GOOG  2010-04-09      90   32.2  unknown

# %%
dt.index=['one','two','three']

# %%
dt
# Out:
#        name        date  shares  price    owner
# one      AA  2001-12-01     100   12.3  unknown
# two     IBM  2012-02-10      30   10.3  unknown
# three  GOOG  2010-04-09      90   32.2  unknown

# %%
# dt.set_index(['name'])
dt
# any column of the DataFrame can be set as index using ‘set_index()’ attribute
# Out:
#        name        date  shares  price    owner
# one      AA  2001-12-01     100   12.3  unknown
# two     IBM  2012-02-10      30   10.3  unknown
# three  GOOG  2010-04-09      90   32.2  unknown

# %%
# access data using column-index
dt['date']
# Out:
# one      2001-12-01
# two      2012-02-10
# three    2010-04-09
# Name: date, dtype: object

# %%
dt.loc['one']
# Out:
# name              AA
# date      2001-12-01
# shares           100
# price           12.3
# owner        unknown
# Name: one, dtype: object

# %%
#dt.set_index(['name'])

# %%
dt.ix['one']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# name              AA
# date      2001-12-01
# shares           100
# price           12.3
# owner        unknown
# Name: one, dtype: object

# %%
dt.ix[:,'name']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# one        AA
# two       IBM
# three    GOOG
# Name: name, dtype: object

# %%
dt.ix[:2,'name']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# one     AA
# two    IBM
# Name: name, dtype: object

# %%
dt.ix[0,'shares']
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# 100

# %%
#del dt['owner']

# %%
dt
# Out:
#        name        date  shares  price    owner
# one      AA  2001-12-01     100   12.3  unknown
# two     IBM  2012-02-10      30   10.3  unknown
# three  GOOG  2010-04-09      90   32.2  unknown

# %%
dt.drop('price',axis=1)
# Out:
#        name        date  shares    owner
# one      AA  2001-12-01     100  unknown
# two     IBM  2012-02-10      30  unknown
# three  GOOG  2010-04-09      90  unknown

# %%
#Chapter two
import pandas as pd

# %%
data=pd.read_csv('countries.csv',index_col=None)
data.head()
# Out:
#        country  year  population
# 0  Afghanistan  1952     8425333
# 1  Afghanistan  1957     9240934
# 2  Afghanistan  1962    10267083
# 3  Afghanistan  1967    11537966
# 4  Afghanistan  1972    13079460

# %%
data=pd.read_csv('countries.csv')
data.tail()
# Out:
#        country  year  population
# 1699  Zimbabwe  1987     9216418
# 1700  Zimbabwe  1992    10704340
# 1701  Zimbabwe  1997    11404948
# 1702  Zimbabwe  2002    11926563
# 1703  Zimbabwe  2007    12311143

# %%
casts = pd.read_csv('cast-Copy1.csv', index_col=None ,encoding='utf-8')
casts.tail()
# Out:
#                           title  year                        name     type  \
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# 74996       Popi voulkanizater  11.0
# 74997  Unicycle Race Attendant   NaN
# 74998       Guidance Counselor  20.0
# 74999        Demon of Toxicity   NaN
# 75000             Laundry Girl  25.0

# %%
casts.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
titles = pd.read_csv('titles-Copy1.csv' )
titles
# Out:
#                                          title  year
# 0                               The Rising Son  1990
# 1                      The Thousand Plane Raid  1969
# 2                             Crucea de piatra  1993
# 3                                      Country  2000
# 4                                   Gaiking II  2011
# 5                                  Medusa (IV)  2015
# 6               The Fresh Air Will Do You Good  2008
# 7                           Alex in Wonderland  1970
# 8                                   L'outsider  2016
# 9                       Do Outro Lado do Mundo  2008
# 10                               Slave by Name  2017
# 11                              The Abductress  2014
# 12                    Poka Makorer Ghar Bosoti  1996
# 13                                   Hi, Buddy  1943
# 14                             Los siete locos  1973
# 15                                  Panic Room  2002
# 16                       Io sono un autarchico  1976
# ...

# %%
titles.head()
# Out:
#                      title  year
# 0           The Rising Son  1990
# 1  The Thousand Plane Raid  1969
# 2         Crucea de piatra  1993
# 3                  Country  2000
# 4               Gaiking II  2011

# %%
pd.set_option('max_rows',10,'max_columns',10)
casts
# Out:
#                           title  year                        name     type  \
# 0                Closet Monster  2015                    Buffy #1    actor
# 1               Suuri illusioni  1985                      Homo $    actor
# 2           Battle of the Sexes  2017                     $hutter    actor
# 3          Secret in Their Eyes  2015                     $hutter    actor
# 4                    Steve Jobs  2015                     $hutter    actor
# ...                         ...   ...                         ...      ...
# 74996  Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# 74997         The Magician King  2004       Tiannah Anastassiades  actress
# 74998        Festival of Lights  2010             Zoe Anastassiou  actress
# 74999                Toxic Tutu  2016             Zoe Anastassiou  actress
# 75000           Fugitive Pieces  2007  Anastassia Anastassopoulou  actress
#
#                      character     n
# ...

# %%
titles
# Out:
#                          title  year
# 0               The Rising Son  1990
# 1      The Thousand Plane Raid  1969
# 2             Crucea de piatra  1993
# 3                      Country  2000
# 4                   Gaiking II  2011
# ...                        ...   ...
# 49995                    Rebel  1970
# 49996                  Suzanne  1996
# 49997                    Bomba  2013
# 49998     Aao Jao Ghar Tumhara  1984
# 49999               Mrs. Munck  1995
#
# [50000 rows x 2 columns]

# %%
len(titles)
# Out:
# 50000

# %%
len(casts)
# Out:
# 75001

# %%
t=titles['title']
t
# Out:
# 0                 The Rising Son
# 1        The Thousand Plane Raid
# 2               Crucea de piatra
# 3                        Country
# 4                     Gaiking II
#                   ...
# 49995                      Rebel
# 49996                    Suzanne
# 49997                      Bomba
# 49998       Aao Jao Ghar Tumhara
# 49999                 Mrs. Munck
# Name: title, Length: 50000, dtype: object

# %%
titles.ix[0]
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.
# title    The Rising Son
# year               1990
# Name: 0, dtype: object

# %%
titles.iloc[0]
# Out:
# title    The Rising Son
# year               1990
# Name: 0, dtype: object

# %%
after85 = titles[titles['year']>1985]

# %%
after85 = titles[titles['year'] > 1985]

# %%
after85
# Out:
#                   title  year
# 0        The Rising Son  1990
# 2      Crucea de piatra  1993
# 3               Country  2000
# 4            Gaiking II  2011
# 5           Medusa (IV)  2015
# ...                 ...   ...
# 49990           Junebug  2005
# 49993    Corruption.Gov  2010
# 49996           Suzanne  1996
# 49997             Bomba  2013
# 49999        Mrs. Munck  1995
#
# [29814 rows x 2 columns]

# %%
bet90_15=titles[(titles['year']>1990) & (titles['year']<2015)]

# %%
bet90_15
# Out:
#                                 title  year
# 2                    Crucea de piatra  1993
# 3                             Country  2000
# 4                          Gaiking II  2011
# 6      The Fresh Air Will Do You Good  2008
# 9              Do Outro Lado do Mundo  2008
# ...                               ...   ...
# 49990                         Junebug  2005
# 49993                  Corruption.Gov  2010
# 49996                         Suzanne  1996
# 49997                           Bomba  2013
# 49999                      Mrs. Munck  1995
#
# [20262 rows x 2 columns]

# %%
t=titles
macbeth=t[t['title']=='Macbeth']

# %%
macbeth
# Out:
#          title  year
# 4226   Macbeth  1913
# 9322   Macbeth  2006
# 11722  Macbeth  2013
# 17166  Macbeth  1997
# 25847  Macbeth  1998

# %%
macbeth=t[t['title']=='Macbeth'].sort_index()

# %%
macbeth.head()
# Out:
#          title  year
# 4226   Macbeth  1913
# 9322   Macbeth  2006
# 11722  Macbeth  2013
# 17166  Macbeth  1997
# 25847  Macbeth  1998

# %%
macbeth=t[t['title']=='Macbeth'].sort_values('year')
macbeth
# Out:
#          title  year
# 4226   Macbeth  1913
# 17166  Macbeth  1997
# 25847  Macbeth  1998
# 9322   Macbeth  2006
# 11722  Macbeth  2013

# %%
casts.iloc[3:10]
# Out:
#                                                title  year  \
# 3                               Secret in Their Eyes  2015
# 4                                         Steve Jobs  2015
# 5                             Straight Outta Compton  2015
# 6                             Straight Outta Compton  2015
# 7                                     For Thy Love 2  2009
# 8  Lapis, Ballpen at Diploma, a True to Life Journey  2014
# 9                                       Desire (III)  2014
#
#                         name   type                               character  \
# 3                    $hutter  actor                         2002 Dodger Fan
# 4                    $hutter  actor                 1988 Opera House Patron
# 5                    $hutter  actor                             Club Patron
# 6                    $hutter  actor                                 Dopeman
# 7               Bee Moe $lim  actor                                  Thug 1
# ...

# %%
c= casts
c['n'].isnull().head()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# Name: n, dtype: bool

# %%
c['n'].notnull().head(3)
# Out:
# 0    True
# 1    True
# 2    True
# Name: n, dtype: bool

# %% [markdown]
# ###

# %%
c[c['n'].isnull()].fillna('NA')
# Out:
#                         title  year                        name     type  \
# 3        Secret in Their Eyes  2015                     $hutter    actor
# 4                  Steve Jobs  2015                     $hutter    actor
# 5      Straight Outta Compton  2015                     $hutter    actor
# 6      Straight Outta Compton  2015                     $hutter    actor
# 7              For Thy Love 2  2009                Bee Moe $lim    actor
# ...                       ...   ...                         ...      ...
# 74984                    Ovum  2015  Christina Rosas Anastasiou  actress
# 74985                  7 avlu  2009         Evmorfia Anastasiou  actress
# 74993     I teliki apopliromi  2013         Mara Anastasopoulou  actress
# 74997       The Magician King  2004       Tiannah Anastassiades  actress
# 74999              Toxic Tutu  2016             Zoe Anastassiou  actress
#
#                            character   n
# 3                    2002 Dodger Fan  NA
# ...

# %%
t=titles
t[t['title']=='Maa']
# Out:
#       title  year
# 38880   Maa  1968

# %%
t[t['title'].str.startswith('Maa ')].head()
# Out:
#                            title  year
# 19              Maa Durga Shakti  1999
# 3046               Maa Aur Mamta  1970
# 7470           Maa Vaibhav Laxmi  1989
# 7933   Maa Kande Aaji Puate Pain  2002
# 17197              Maa al-Khatar  2016

# %%
t['year'].value_counts().head()
# Out:
# 2016    2363
# 2017    2138
# 2015    1849
# 2014    1701
# 2013    1609
# Name: year, dtype: int64

# %%
import matplotlib.pyplot as plt

# %%
t=titles
p=t['year'].value_counts().sort_index()
p.plot()
plt.show()

# %%
cs=t.groupby(['year']).size()
cs.plot()

plt.show()

# %%
c=casts
c=c[c['name']=='Aaron Abrams']
m=c.groupby(['year','title']).size()
m
# Out:
# year  title
# 2003  The In-Laws                             1
#       The Visual Bible: The Gospel of John    1
# 2004  Resident Evil: Apocalypse               1
#       Siblings                                1
# 2005  Cinderella Man                          1
#                                              ..
# 2015  Closet Monster                          1
#       Regression                              1
# 2017  #FromJennifer                           1
#       The Go-Getters                          1
# 2018  Code 8                                  1
# Length: 22, dtype: int64

# %%
m.plot()
plt.show()

# %%
c=casts
c=c[c['name']=='Aaron Abrams']
m=c.groupby(['year']).size()
m
m.plot()
plt.show()

# %%
c.groupby(['year']).n.max()
c
c.plot()
plt.show()

# %%
c.groupby(['year']).n.min()
# Out:
# year
# 2003    17.0
# 2004     9.0
# 2005     8.0
# 2006     NaN
# 2007     1.0
#         ...
# 2011     4.0
# 2013     3.0
# 2015     1.0
# 2017     1.0
# 2018     NaN
# Name: n, Length: 12, dtype: float64

# %%
c.groupby(['year']).n.mean()
# Out:
# year
# 2003    17.0
# 2004    14.5
# 2005    37.5
# 2006     NaN
# 2007    16.5
#         ...
# 2011    13.8
# 2013     3.0
# 2015     6.5
# 2017     1.0
# 2018     NaN
# Name: n, Length: 12, dtype: float64

# %%
c.plot()
plt.show()

# %%
m=casts['year']
print(m)
c=casts['year']//10*10
print(c)
l=casts.groupby(c).n.size()
print(l)
# Out:
# 0        2015
# 1        1985
# 2        2017
# 3        2015
# 4        2015
#          ...
# 74996    2011
# 74997    2004
# 74998    2010
# 74999    2016
# 75000    2007
# Name: year, Length: 75001, dtype: int64
# 0        2010
# 1        1980
# 2        2010
# 3        2010
# 4        2010
#          ...
# 74996    2010
# 74997    2000
# 74998    2010
# 74999    2010
# 75000    2000
# Name: year, Length: 75001, dtype: int64
# year
# 1910      669
# 1920     1121
# 1930     3448
# 1940     3997
# 1950     3892
#         ...
# 1980     5554
# 1990     7652
# 2000    16199
# 2010    24376
# 2020        7
# Name: n, Length: 12, dtype: int64

# %%
l.plot()
plt.show()

# %%
c=casts
l=c['year']//10*10
m=c.groupby([l,'type']).size()
# Out:
# year  type
# 1910  actor        384
#       actress      285
# 1920  actor        710
#       actress      411
# 1930  actor       2628
#                  ...
# 2000  actress     5831
# 2010  actor      15523
#       actress     8853
# 2020  actor          4
#       actress        3
# Length: 24, dtype: int64

# %%
c_decade=c.groupby(['type',c['year']//10*10]).size()
c_decade
# Out:
# type     year
# actor    1910     384
#          1920     710
#          1930    2628
#          1940    3014
#          1950    2877
#                  ...
# actress  1980    1989
#          1990    2544
#          2000    5831
#          2010    8853
#          2020       3
# Length: 24, dtype: int64

# %%
o=c_decade.unstack()
o
# Out:
# year     1910  1920  1930  1940  1950  ...   1980  1990   2000   2010  2020
# type                                   ...
# actor     384   710  2628  3014  2877  ...   3565  5108  10368  15523     4
# actress   285   411   820   983  1015  ...   1989  2544   5831   8853     3
#
# [2 rows x 12 columns]

# %%
o.plot()
plt.show()

# %%
o.plot(kind='bar')
plt.show()

# %%
o=c_decade.unstack(0)
o
# Out:
# type  actor  actress
# year
# 1910    384      285
# 1920    710      411
# 1930   2628      820
# 1940   3014      983
# 1950   2877     1015
# ...     ...      ...
# 1980   3565     1989
# 1990   5108     2544
# 2000  10368     5831
# 2010  15523     8853
# 2020      4        3
#
# [12 rows x 2 columns]

# %%
o.plot(kind='bar')
plt.show()

# %%
release=pd.read_csv('release_dates-Copy1.csv',index_col=None)
release.head()
# Out:
#                     title  year      country        date
# 0   #73, Shaanthi Nivaasa  2007        India  2007-06-15
# 1                 #Beings  2015      Romania  2015-01-29
# 2               #Declimax  2018  Netherlands  2018-01-21
# 3  #Ewankosau saranghaeyo  2015  Philippines  2015-01-21
# 4                 #Horror  2015          USA  2015-11-20

# %%
casts.head()
# Out:
#                   title  year      name   type                character     n
# 0        Closet Monster  2015  Buffy #1  actor                  Buffy 4  31.0
# 1       Suuri illusioni  1985    Homo $  actor                   Guests  22.0
# 2   Battle of the Sexes  2017   $hutter  actor          Bobby Riggs Fan  10.0
# 3  Secret in Their Eyes  2015   $hutter  actor          2002 Dodger Fan   NaN
# 4            Steve Jobs  2015   $hutter  actor  1988 Opera House Patron   NaN

# %%
c=casts
c_ame=c[c['title']=='Amelia']
c_ame
# Out:
#         title  year            name   type    character     n
# 5767   Amelia  2009    Aaron Abrams  actor  Slim Gordon   8.0
# 23319  Amelia  2009  Jeremy Akerman  actor      Sheriff  19.0

# %%
r=release
rel_ame=r[r['title']=='Amelia']
rel_ame
# Out:
#         title  year      country        date
# 20543  Amelia  1966       Mexico  1966-03-10
# 20544  Amelia  2009       Canada  2009-10-23
# 20545  Amelia  2009          USA  2009-10-23
# 20546  Amelia  2009    Australia  2009-11-12
# 20547  Amelia  2009    Singapore  2009-11-12
# ...       ...   ...          ...         ...
# 20563  Amelia  2009  Netherlands  2010-03-25
# 20564  Amelia  2009       Brazil  2010-03-26
# 20565  Amelia  2009       France  2010-04-14
# 20566  Amelia  2009      Germany  2010-06-17
# 20567  Amelia  2009        Japan  2010-11-27
#
# [25 rows x 4 columns]

# %%
c_ame.merge(rel_ame)
# Out:
#      title  year            name   type    character     n      country  \
# 0   Amelia  2009    Aaron Abrams  actor  Slim Gordon   8.0       Canada
# 1   Amelia  2009    Aaron Abrams  actor  Slim Gordon   8.0          USA
# 2   Amelia  2009    Aaron Abrams  actor  Slim Gordon   8.0    Australia
# 3   Amelia  2009    Aaron Abrams  actor  Slim Gordon   8.0    Singapore
# 4   Amelia  2009    Aaron Abrams  actor  Slim Gordon   8.0      Ireland
# ..     ...   ...             ...    ...          ...   ...          ...
# 43  Amelia  2009  Jeremy Akerman  actor      Sheriff  19.0  Netherlands
# 44  Amelia  2009  Jeremy Akerman  actor      Sheriff  19.0       Brazil
# 45  Amelia  2009  Jeremy Akerman  actor      Sheriff  19.0       France
# 46  Amelia  2009  Jeremy Akerman  actor      Sheriff  19.0      Germany
# 47  Amelia  2009  Jeremy Akerman  actor      Sheriff  19.0        Japan
#
#           date
# 0   2009-10-23
# 1   2009-10-23
# 2   2009-11-12
# 3   2009-11-12
# 4   2009-11-13
# ...

# %%
k=c[c['name']=='Aaron Abrams']
k
# Out:
#                                      title  year          name   type  \
# 5765                         #FromJennifer  2017  Aaron Abrams  actor
# 5766                    388 Arletta Avenue  2011  Aaron Abrams  actor
# 5767                                Amelia  2009  Aaron Abrams  actor
# 5768         At Home by Myself... with You  2009  Aaron Abrams  actor
# 5769                        Cinderella Man  2005  Aaron Abrams  actor
# ...                                    ...   ...           ...    ...
# 5783                        The Go-Getters  2017  Aaron Abrams  actor
# 5784                           The In-Laws  2003  Aaron Abrams  actor
# 5785  The Visual Bible: The Gospel of John  2003  Aaron Abrams  actor
# 5786                  Young People Fucking  2007  Aaron Abrams  actor
# 5787                                  Zoom  2006  Aaron Abrams  actor
#
#                    character     n
# 5765          Ralph Sinclair   NaN
# 5766                    Alex   4.0
# ...

# %%
c_costar=k.merge(c ,on=['title','year'])
c_costar=c_costar[c_costar['name_y']!='Aaron Abrams']
c_costar
# Out:
#                  title  year        name_x type_x         character_x   n_x  \
# 1        #FromJennifer  2017  Aaron Abrams  actor      Ralph Sinclair   NaN
# 2   388 Arletta Avenue  2011  Aaron Abrams  actor                Alex   4.0
# 5               Amelia  2009  Aaron Abrams  actor         Slim Gordon   8.0
# 8       Cinderella Man  2005  Aaron Abrams  actor            1928 Fan  67.0
# 9       Cinderella Man  2005  Aaron Abrams  actor            1928 Fan  67.0
# ..                 ...   ...           ...    ...                 ...   ...
# 51                Zoom  2006  Aaron Abrams  actor  Corporal Lipscombe   NaN
# 53                Zoom  2006  Aaron Abrams  actor  Corporal Lipscombe   NaN
# 54                Zoom  2006  Aaron Abrams  actor  Corporal Lipscombe   NaN
# 55                Zoom  2006  Aaron Abrams  actor  Corporal Lipscombe   NaN
# 56                Zoom  2006  Aaron Abrams  actor  Corporal Lipscombe   NaN
#
# ...

# %%
# %%time
c[c['title']=='Macbeth']
# Out:
# Wall time: 32 ms
#          title  year                 name     type        character     n
# 12868  Macbeth  2015       Darren Adamson    actor          Soldier   NaN
# 22302  Macbeth  1916  Spottiswoode Aitken    actor           Duncan   4.0
# 25855  Macbeth  1948          Robert Alan    actor   Third Murderer   NaN
# 26990  Macbeth  2016        John Albasiny    actor           Doctor   NaN
# 38090  Macbeth  1948       William Alland    actor  Second Murderer  18.0
# 40639  Macbeth  1997         Stevie Allen    actor         Murderer  21.0
# 60543  Macbeth  2014          Moyo Akand?  actress            Witch   NaN
# 63776  Macbeth  1916           Mary Alden  actress     Lady Macduff   6.0

# %%
# %%timeit
c[c['title']=='Macbeth']
# Out:
# 28.9 ms ± 2.55 ms per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %%
c=casts.set_index(['title'])
c
# Out:
#                           year                        name     type  \
# title
# Closet Monster            2015                    Buffy #1    actor
# Suuri illusioni           1985                      Homo $    actor
# Battle of the Sexes       2017                     $hutter    actor
# Secret in Their Eyes      2015                     $hutter    actor
# Steve Jobs                2015                     $hutter    actor
# ...                        ...                         ...      ...
# Mia fora kai ena... moro  2011     Penelope Anastasopoulou  actress
# The Magician King         2004       Tiannah Anastassiades  actress
# Festival of Lights        2010             Zoe Anastassiou  actress
# Toxic Tutu                2016             Zoe Anastassiou  actress
# Fugitive Pieces           2007  Anastassia Anastassopoulou  actress
#
#                                         character     n
# title
# Closet Monster                            Buffy 4  31.0
# ...

# %%
# %%time


c.loc['Macbeth']
# Out:
# Wall time: 12 ms
#          year                 name     type        character     n
# title
# Macbeth  2015       Darren Adamson    actor          Soldier   NaN
# Macbeth  1916  Spottiswoode Aitken    actor           Duncan   4.0
# Macbeth  1948          Robert Alan    actor   Third Murderer   NaN
# Macbeth  2016        John Albasiny    actor           Doctor   NaN
# Macbeth  1948       William Alland    actor  Second Murderer  18.0
# Macbeth  1997         Stevie Allen    actor         Murderer  21.0
# Macbeth  2014          Moyo Akand?  actress            Witch   NaN
# Macbeth  1916           Mary Alden  actress     Lady Macduff   6.0

# %%
# %%timeit

c.loc['Macbeth']
# Out:
# 10.8 ms ± 1.02 ms per loop (mean ± std. dev. of 7 runs, 100 loops each)

# %%
cs=casts.set_index('title').sort_index()
cs
# Out:
#                             year                name     type  \
# title
# #1 Serial Killer            2013       Michael Alton    actor
# #DigitalLivesMatter         2016          Rashan Ali  actress
# #FromJennifer               2017  Christian Ackerman    actor
# #FromJennifer               2017        Aaron Abrams    actor
# #Horror                     2015          Emma Adler  actress
# ...                          ...                 ...      ...
# w Delta z                   2007       Barbara Adair  actress
# xXx: Return of Xander Cage  2017        Julie Abcede    actor
# xXx: Return of Xander Cage  2017         Jeimi Abila  actress
# xXx: Return of Xander Cage  2017       Wayne Ambrose    actor
# xXx: State of the Union     2005       Robert Alonzo    actor
#
#                                     character     n
# title
# #1 Serial Killer            Detective Roberts  17.0
# #DigitalLivesMatter             News Reporter   NaN
# ...

# %%
# %%time
c.loc['Macbeth'].tail()
# Out:
# Wall time: 13 ms
#          year            name     type        character     n
# title
# Macbeth  2016   John Albasiny    actor           Doctor   NaN
# Macbeth  1948  William Alland    actor  Second Murderer  18.0
# Macbeth  1997    Stevie Allen    actor         Murderer  21.0
# Macbeth  2014     Moyo Akand?  actress            Witch   NaN
# Macbeth  1916      Mary Alden  actress     Lady Macduff   6.0

# %%
###Multiple indexing###
co=casts.set_index(['title','n']).sort_index()
co
# Out:
#                                  year                name     type  \
# title                      n
# #1 Serial Killer           17.0  2013       Michael Alton    actor
# #DigitalLivesMatter        NaN   2016          Rashan Ali  actress
# #FromJennifer              NaN   2017        Aaron Abrams    actor
#                            NaN   2017  Christian Ackerman    actor
# #Horror                    1.0   2015          Emma Adler  actress
# ...                               ...                 ...      ...
# w Delta z                  8.0   2007       Barbara Adair  actress
# xXx: Return of Xander Cage 34.0  2017       Wayne Ambrose    actor
#                            64.0  2017         Jeimi Abila  actress
#                            84.0  2017        Julie Abcede    actor
# xXx: State of the Union    NaN   2005       Robert Alonzo    actor
#
#                                          character
# title                      n
# ...

# %%
co.loc['Macbeth']
# Out:
#        year                 name     type        character
# n
#  4.0   1916  Spottiswoode Aitken    actor           Duncan
#  6.0   1916           Mary Alden  actress     Lady Macduff
#  18.0  1948       William Alland    actor  Second Murderer
#  21.0  1997         Stevie Allen    actor         Murderer
# NaN    2015       Darren Adamson    actor          Soldier
# NaN    1948          Robert Alan    actor   Third Murderer
# NaN    2016        John Albasiny    actor           Doctor
# NaN    2014          Moyo Akand?  actress            Witch

# %%
co.loc['Macbeth'].loc[4:18]
# Out:
#       year                 name     type        character
# n
# 4.0   1916  Spottiswoode Aitken    actor           Duncan
# 6.0   1916           Mary Alden  actress     Lady Macduff
# 18.0  1948       William Alland    actor  Second Murderer

# %%
co.loc['Macbeth'].loc[4]
# Out:
# year                        1916
# name         Spottiswoode Aitken
# type                       actor
# character                 Duncan
# Name: 4.0, dtype: object

# %%
co.reset_index('n')
# Out:
#                                n  year                name     type  \
# title
# #1 Serial Killer            17.0  2013       Michael Alton    actor
# #DigitalLivesMatter          NaN  2016          Rashan Ali  actress
# #FromJennifer                NaN  2017        Aaron Abrams    actor
# #FromJennifer                NaN  2017  Christian Ackerman    actor
# #Horror                      1.0  2015          Emma Adler  actress
# ...                          ...   ...                 ...      ...
# w Delta z                    8.0  2007       Barbara Adair  actress
# xXx: Return of Xander Cage  34.0  2017       Wayne Ambrose    actor
# xXx: Return of Xander Cage  64.0  2017         Jeimi Abila  actress
# xXx: Return of Xander Cage  84.0  2017        Julie Abcede    actor
# xXx: State of the Union      NaN  2005       Robert Alonzo    actor
#
#                                     character
# title
# #1 Serial Killer            Detective Roberts
# ...

# %%
import csv

# %%
t=list(csv.DictReader(open('titles-Copy1.csv')))
t[:10]
# Out:
# [OrderedDict([('title', 'The Rising Son'), ('year', '1990')]),
#  OrderedDict([('title', 'The Thousand Plane Raid'), ('year', '1969')]),
#  OrderedDict([('title', 'Crucea de piatra'), ('year', '1993')]),
#  OrderedDict([('title', 'Country'), ('year', '2000')]),
#  OrderedDict([('title', 'Gaiking II'), ('year', '2011')]),
#  OrderedDict([('title', 'Medusa (IV)'), ('year', '2015')]),
#  OrderedDict([('title', 'The Fresh Air Will Do You Good'), ('year', '2008')]),
#  OrderedDict([('title', 'Alex in Wonderland'), ('year', '1970')]),
#  OrderedDict([('title', "L'outsider"), ('year', '2016')]),
#  OrderedDict([('title', 'Do Outro Lado do Mundo'), ('year', '2008')])]
